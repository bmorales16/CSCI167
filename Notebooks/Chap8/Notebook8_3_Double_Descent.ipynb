# %% [markdown]
# <a href="https://colab.research.google.com/github/bmorales16/CSCI167/blob/main/Notebook8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-lbdt3ysw
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-lbdt3ysw
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c1c710ce16a5a6fd6f26d83f7611ee4c7fd618614d31579ea711dfa74977bad6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hxquraiy/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# The training error will approximate to zero but not quite to zero, when the capacity parameters are greater than number of training samples that allow interpolation.
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# The first minima occurs before interpolation, my guess anywhere between 1000 and 2000.
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# I predict the maximum of the double descent curve to appear at around 3,500 to 4000.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.300053, train error 90.55,  test loss 2.298656, test error 90.95
# Epoch   100, train loss 1.922702, train error 71.97,  test loss 1.777085, test error 70.62
# Epoch   200, train loss 1.890716, train error 71.18,  test loss 1.729897, test error 69.05
# Epoch   300, train loss 1.861433, train error 70.53,  test loss 1.704684, test error 67.28
# Epoch   400, train loss 1.851356, train error 71.38,  test loss 1.686997, test error 67.57
# Epoch   500, train loss 1.839342, train error 69.50,  test loss 1.684401, test error 67.15
# Epoch   600, train loss 1.842469, train error 69.57,  test loss 1.682174, test error 67.60
# Epoch   700, train loss 1.841125, train error 70.22,  test loss 1.681446, test error 68.07
# Epoch   800, train loss 1.840351, train error 70.28,  test loss 1.699764, test error 67.55
# Epoch   900, train loss 1.838253, train error 69.75,  test loss 1.685254, test error 67.15
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301152, train error 88.03,  test loss 2.304330, test error 89.28
# Epoch   100, train loss 1.783439, train error 65.20,  test loss 1.609309, test error 62.22
# Epoch   200, train loss 1.741473, train error 64.22,  test loss 1.586319, test error 62.33
# Epoch   300, train loss 1.733904, train error 64.28,  test loss 1.569991, test error 61.65
# Epoch   400, train loss 1.725957, train error 64.15,  test loss 1.575527, test error 61.85
# Epoch   500, train loss 1.723538, train error 64.62,  test loss 1.582412, test error 61.58
# Epoch   600, train loss 1.722059, train error 63.28,  test loss 1.575650, test error 60.90
# Epoch   700, train loss 1.723787, train error 63.55,  test loss 1.570259, test error 61.28
# Epoch   800, train loss 1.723840, train error 63.40,  test loss 1.577366, test error 61.25
# Epoch   900, train loss 1.721618, train error 64.28,  test loss 1.582799, test error 61.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.237283, train error 84.03,  test loss 2.220225, test error 82.85
# Epoch   100, train loss 1.671323, train error 60.55,  test loss 1.492463, test error 59.15
# Epoch   200, train loss 1.643189, train error 58.88,  test loss 1.488691, test error 59.05
# Epoch   300, train loss 1.628407, train error 58.85,  test loss 1.484810, test error 58.30
# Epoch   400, train loss 1.623839, train error 58.20,  test loss 1.489471, test error 58.67
# Epoch   500, train loss 1.623756, train error 58.53,  test loss 1.492686, test error 58.35
# Epoch   600, train loss 1.626688, train error 58.17,  test loss 1.486580, test error 58.95
# Epoch   700, train loss 1.618102, train error 58.85,  test loss 1.494973, test error 58.75
# Epoch   800, train loss 1.620248, train error 59.17,  test loss 1.497290, test error 59.15
# Epoch   900, train loss 1.617500, train error 59.05,  test loss 1.501424, test error 58.88
# Training model with   8 hidden variables
# Epoch     0, train loss 2.294050, train error 87.85,  test loss 2.301246, test error 88.10
# Epoch   100, train loss 1.596092, train error 57.45,  test loss 1.457252, test error 55.45
# Epoch   200, train loss 1.519832, train error 52.40,  test loss 1.411314, test error 51.80
# Epoch   300, train loss 1.486825, train error 50.85,  test loss 1.355019, test error 49.78
# Epoch   400, train loss 1.475389, train error 50.80,  test loss 1.349371, test error 49.38
# Epoch   500, train loss 1.472766, train error 51.35,  test loss 1.344883, test error 48.83
# Epoch   600, train loss 1.461160, train error 50.80,  test loss 1.347857, test error 49.15
# Epoch   700, train loss 1.456986, train error 50.40,  test loss 1.335281, test error 48.80
# Epoch   800, train loss 1.459608, train error 50.42,  test loss 1.339501, test error 48.22
# Epoch   900, train loss 1.448593, train error 50.33,  test loss 1.334994, test error 48.88
# Training model with  10 hidden variables
# Epoch     0, train loss 2.255174, train error 83.65,  test loss 2.243191, test error 83.15
# Epoch   100, train loss 1.442391, train error 48.65,  test loss 1.273968, test error 47.03
# Epoch   200, train loss 1.402859, train error 47.25,  test loss 1.245798, test error 45.45
# Epoch   300, train loss 1.379898, train error 46.75,  test loss 1.241586, test error 46.30
# Epoch   400, train loss 1.366791, train error 45.67,  test loss 1.254656, test error 46.30
# Epoch   500, train loss 1.351183, train error 45.00,  test loss 1.244402, test error 45.88
# Epoch   600, train loss 1.345785, train error 45.22,  test loss 1.259843, test error 45.80
# Epoch   700, train loss 1.343606, train error 45.05,  test loss 1.270972, test error 46.42
# Epoch   800, train loss 1.342892, train error 45.08,  test loss 1.270824, test error 45.90
# Epoch   900, train loss 1.339234, train error 45.17,  test loss 1.274073, test error 46.30
# Training model with  14 hidden variables
# Epoch     0, train loss 2.260502, train error 84.30,  test loss 2.250149, test error 83.60
# Epoch   100, train loss 1.449050, train error 49.58,  test loss 1.375131, test error 52.03
# Epoch   200, train loss 1.358008, train error 45.70,  test loss 1.316688, test error 48.85
# Epoch   300, train loss 1.318559, train error 44.50,  test loss 1.339532, test error 49.70
# Epoch   400, train loss 1.300045, train error 43.95,  test loss 1.345718, test error 49.90
# Epoch   500, train loss 1.280010, train error 43.17,  test loss 1.361308, test error 49.62
# Epoch   600, train loss 1.274330, train error 42.25,  test loss 1.361952, test error 49.55
# Epoch   700, train loss 1.257489, train error 42.20,  test loss 1.369280, test error 48.62
# Epoch   800, train loss 1.258672, train error 42.62,  test loss 1.397940, test error 49.42
# Epoch   900, train loss 1.246649, train error 42.35,  test loss 1.393597, test error 48.75
# Training model with  18 hidden variables
# Epoch     0, train loss 2.228274, train error 83.15,  test loss 2.224544, test error 82.95
# Epoch   100, train loss 1.334650, train error 44.42,  test loss 1.267940, test error 47.28
# Epoch   200, train loss 1.235417, train error 41.30,  test loss 1.307216, test error 49.05
# Epoch   300, train loss 1.198626, train error 40.38,  test loss 1.359444, test error 50.20
# Epoch   400, train loss 1.179115, train error 39.38,  test loss 1.377953, test error 50.42
# Epoch   500, train loss 1.168858, train error 39.47,  test loss 1.427561, test error 52.10
# Epoch   600, train loss 1.159443, train error 39.62,  test loss 1.433058, test error 51.30
# Epoch   700, train loss 1.148017, train error 38.40,  test loss 1.471915, test error 52.28
# Epoch   800, train loss 1.141963, train error 38.62,  test loss 1.471760, test error 52.00
# Epoch   900, train loss 1.140062, train error 38.42,  test loss 1.479016, test error 51.92
# Training model with  22 hidden variables
# Epoch     0, train loss 2.177835, train error 80.60,  test loss 2.172755, test error 80.25
# Epoch   100, train loss 1.265448, train error 41.78,  test loss 1.299032, test error 47.50
# Epoch   200, train loss 1.142426, train error 38.42,  test loss 1.353816, test error 48.35
# Epoch   300, train loss 1.073806, train error 36.25,  test loss 1.427978, test error 49.92
# Epoch   400, train loss 1.037057, train error 34.35,  test loss 1.486196, test error 50.30
# Epoch   500, train loss 1.018296, train error 34.82,  test loss 1.542879, test error 49.90
# Epoch   600, train loss 0.992318, train error 33.15,  test loss 1.609438, test error 51.15
# Epoch   700, train loss 0.986164, train error 33.40,  test loss 1.687582, test error 52.78
# Epoch   800, train loss 0.959028, train error 32.60,  test loss 1.709448, test error 51.72
# Epoch   900, train loss 0.952496, train error 31.90,  test loss 1.748905, test error 52.78
# Training model with  26 hidden variables
# Epoch     0, train loss 2.162298, train error 79.32,  test loss 2.153752, test error 80.68
# Epoch   100, train loss 1.182263, train error 39.85,  test loss 1.333733, test error 49.08
# Epoch   200, train loss 1.030691, train error 35.72,  test loss 1.463487, test error 51.58
# Epoch   300, train loss 0.964612, train error 33.55,  test loss 1.579610, test error 51.85
# Epoch   400, train loss 0.912261, train error 31.85,  test loss 1.724567, test error 53.08
# Epoch   500, train loss 0.889756, train error 31.40,  test loss 1.864358, test error 54.15
# Epoch   600, train loss 0.868464, train error 31.32,  test loss 1.949909, test error 53.92
# Epoch   700, train loss 0.848580, train error 30.75,  test loss 2.016368, test error 54.08
# Epoch   800, train loss 0.851471, train error 31.32,  test loss 2.146770, test error 55.20
# Epoch   900, train loss 0.816969, train error 29.53,  test loss 2.214154, test error 55.15
# Training model with  30 hidden variables
# Epoch     0, train loss 2.137737, train error 79.45,  test loss 2.091903, test error 78.72
# Epoch   100, train loss 1.108794, train error 36.22,  test loss 1.424498, test error 50.60
# Epoch   200, train loss 0.932717, train error 31.68,  test loss 1.582305, test error 51.92
# Epoch   300, train loss 0.834269, train error 27.68,  test loss 1.794527, test error 52.40
# Epoch   400, train loss 0.774235, train error 25.00,  test loss 1.943522, test error 53.08
# Epoch   500, train loss 0.747138, train error 24.38,  test loss 2.109990, test error 54.47
# Epoch   600, train loss 0.715615, train error 24.45,  test loss 2.298343, test error 54.22
# Epoch   700, train loss 0.708859, train error 24.70,  test loss 2.402962, test error 55.05
# Epoch   800, train loss 0.667158, train error 21.95,  test loss 2.496011, test error 54.55
# Epoch   900, train loss 0.666886, train error 22.97,  test loss 2.616080, test error 54.50
# Training model with  35 hidden variables
# Epoch     0, train loss 2.155475, train error 80.30,  test loss 2.138703, test error 79.05
# Epoch   100, train loss 1.018189, train error 32.62,  test loss 1.386069, test error 48.58
# Epoch   200, train loss 0.761019, train error 24.80,  test loss 1.681963, test error 50.75
# Epoch   300, train loss 0.638989, train error 21.72,  test loss 2.125041, test error 53.05
# Epoch   400, train loss 0.570737, train error 19.32,  test loss 2.583920, test error 54.33
# Epoch   500, train loss 0.529717, train error 17.85,  test loss 2.934454, test error 55.80
# Epoch   600, train loss 0.496747, train error 16.70,  test loss 3.337242, test error 56.38
# Epoch   700, train loss 0.457517, train error 15.40,  test loss 3.663106, test error 56.10
# Epoch   800, train loss 0.457948, train error 15.95,  test loss 4.073213, test error 56.62
# Epoch   900, train loss 0.425509, train error 14.30,  test loss 4.290300, test error 56.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.094599, train error 77.90,  test loss 2.059006, test error 76.88
# Epoch   100, train loss 0.943389, train error 31.35,  test loss 1.474805, test error 49.28
# Epoch   200, train loss 0.649898, train error 20.80,  test loss 1.932614, test error 52.47
# Epoch   300, train loss 0.522535, train error 17.45,  test loss 2.527451, test error 53.55
# Epoch   400, train loss 0.438051, train error 15.20,  test loss 3.108500, test error 54.62
# Epoch   500, train loss 0.379116, train error 13.22,  test loss 3.629206, test error 55.05
# Epoch   600, train loss 0.359179, train error 12.57,  test loss 4.204105, test error 54.38
# Epoch   700, train loss 0.272726, train error 9.53,  test loss 4.727250, test error 55.25
# Epoch   800, train loss 0.286831, train error 10.38,  test loss 5.527182, test error 56.58
# Epoch   900, train loss 0.291044, train error 10.70,  test loss 6.024788, test error 55.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.139596, train error 78.03,  test loss 2.110622, test error 76.90
# Epoch   100, train loss 0.813282, train error 25.55,  test loss 1.528147, test error 50.97
# Epoch   200, train loss 0.481647, train error 15.53,  test loss 2.295607, test error 54.25
# Epoch   300, train loss 0.307096, train error 9.38,  test loss 3.357608, test error 56.12
# Epoch   400, train loss 0.214347, train error 6.88,  test loss 4.637163, test error 56.20
# Epoch   500, train loss 0.197618, train error 6.68,  test loss 5.954842, test error 57.08
# Epoch   600, train loss 0.023449, train error 0.03,  test loss 7.163484, test error 57.20
# Epoch   700, train loss 0.013433, train error 0.00,  test loss 8.065277, test error 57.28
# Epoch   800, train loss 0.009239, train error 0.00,  test loss 8.735067, test error 57.53
# Epoch   900, train loss 0.007014, train error 0.00,  test loss 9.257463, test error 57.53
# Training model with  50 hidden variables
# Epoch     0, train loss 2.054067, train error 75.30,  test loss 1.996159, test error 75.50
# Epoch   100, train loss 0.726381, train error 22.80,  test loss 1.574904, test error 51.28
# Epoch   200, train loss 0.354307, train error 10.68,  test loss 2.628072, test error 54.83
# Epoch   300, train loss 0.220712, train error 6.85,  test loss 4.247272, test error 55.42
# Epoch   400, train loss 0.031341, train error 0.03,  test loss 5.830647, test error 56.35
# Epoch   500, train loss 0.012519, train error 0.00,  test loss 6.813409, test error 56.65
# Epoch   600, train loss 0.007216, train error 0.00,  test loss 7.441329, test error 56.88
# Epoch   700, train loss 0.005163, train error 0.00,  test loss 7.899652, test error 57.03
# Epoch   800, train loss 0.004036, train error 0.00,  test loss 8.253966, test error 57.00
# Epoch   900, train loss 0.003260, train error 0.00,  test loss 8.549373, test error 57.05
# Training model with  55 hidden variables
# Epoch     0, train loss 2.070992, train error 78.10,  test loss 2.026776, test error 77.07
# Epoch   100, train loss 0.594805, train error 16.90,  test loss 1.637791, test error 51.00
# Epoch   200, train loss 0.183022, train error 3.88,  test loss 3.164874, test error 54.83
# Epoch   300, train loss 0.034930, train error 0.03,  test loss 4.790301, test error 55.15
# Epoch   400, train loss 0.013523, train error 0.00,  test loss 5.723078, test error 55.35
# Epoch   500, train loss 0.008096, train error 0.00,  test loss 6.296108, test error 55.80
# Epoch   600, train loss 0.005727, train error 0.00,  test loss 6.720516, test error 55.78
# Epoch   700, train loss 0.004241, train error 0.00,  test loss 7.047157, test error 55.67
# Epoch   800, train loss 0.003373, train error 0.00,  test loss 7.323047, test error 56.08
# Epoch   900, train loss 0.002784, train error 0.00,  test loss 7.555773, test error 55.88
# Training model with  60 hidden variables
# Epoch     0, train loss 2.020144, train error 76.18,  test loss 1.958636, test error 75.22
# Epoch   100, train loss 0.532861, train error 15.55,  test loss 1.692750, test error 50.40
# Epoch   200, train loss 0.102310, train error 0.85,  test loss 3.377185, test error 53.97
# Epoch   300, train loss 0.019977, train error 0.03,  test loss 4.743790, test error 54.38
# Epoch   400, train loss 0.009262, train error 0.00,  test loss 5.438661, test error 54.30
# Epoch   500, train loss 0.005766, train error 0.00,  test loss 5.875103, test error 54.20
# Epoch   600, train loss 0.004104, train error 0.00,  test loss 6.207562, test error 54.25
# Epoch   700, train loss 0.003159, train error 0.00,  test loss 6.471594, test error 54.22
# Epoch   800, train loss 0.002536, train error 0.00,  test loss 6.680330, test error 54.10
# Epoch   900, train loss 0.002099, train error 0.00,  test loss 6.859585, test error 54.10
# Training model with  70 hidden variables
# Epoch     0, train loss 2.057303, train error 76.85,  test loss 1.991308, test error 75.15
# Epoch   100, train loss 0.355994, train error 9.28,  test loss 1.975502, test error 52.75
# Epoch   200, train loss 0.029962, train error 0.00,  test loss 3.582059, test error 53.40
# Epoch   300, train loss 0.010241, train error 0.00,  test loss 4.325217, test error 53.53
# Epoch   400, train loss 0.005777, train error 0.00,  test loss 4.748360, test error 53.58
# Epoch   500, train loss 0.003916, train error 0.00,  test loss 5.045351, test error 53.58
# Epoch   600, train loss 0.002919, train error 0.00,  test loss 5.273593, test error 53.50
# Epoch   700, train loss 0.002287, train error 0.00,  test loss 5.457370, test error 53.65
# Epoch   800, train loss 0.001872, train error 0.00,  test loss 5.610790, test error 53.80
# Epoch   900, train loss 0.001576, train error 0.00,  test loss 5.743030, test error 53.75
# Training model with  80 hidden variables
# Epoch     0, train loss 2.016821, train error 76.30,  test loss 1.953214, test error 76.18
# Epoch   100, train loss 0.242186, train error 4.30,  test loss 2.040907, test error 51.12
# Epoch   200, train loss 0.020776, train error 0.00,  test loss 3.417373, test error 52.17
# Epoch   300, train loss 0.008261, train error 0.00,  test loss 3.984863, test error 52.62
# Epoch   400, train loss 0.004883, train error 0.00,  test loss 4.321755, test error 52.58
# Epoch   500, train loss 0.003365, train error 0.00,  test loss 4.563674, test error 52.60
# Epoch   600, train loss 0.002525, train error 0.00,  test loss 4.744545, test error 52.58
# Epoch   700, train loss 0.001999, train error 0.00,  test loss 4.893628, test error 52.70
# Epoch   800, train loss 0.001643, train error 0.00,  test loss 5.020206, test error 52.72
# Epoch   900, train loss 0.001388, train error 0.00,  test loss 5.129991, test error 52.67
# Training model with  90 hidden variables
# Epoch     0, train loss 2.019634, train error 74.75,  test loss 1.965948, test error 75.60
# Epoch   100, train loss 0.153768, train error 1.55,  test loss 2.218705, test error 51.78
# Epoch   200, train loss 0.015107, train error 0.00,  test loss 3.305127, test error 51.60
# Epoch   300, train loss 0.006603, train error 0.00,  test loss 3.756829, test error 51.67
# Epoch   400, train loss 0.004029, train error 0.00,  test loss 4.035990, test error 51.88
# Epoch   500, train loss 0.002827, train error 0.00,  test loss 4.235961, test error 51.83
# Epoch   600, train loss 0.002150, train error 0.00,  test loss 4.393104, test error 51.83
# Epoch   700, train loss 0.001719, train error 0.00,  test loss 4.521377, test error 52.00
# Epoch   800, train loss 0.001422, train error 0.00,  test loss 4.630582, test error 52.03
# Epoch   900, train loss 0.001208, train error 0.00,  test loss 4.723962, test error 52.00
# Training model with 100 hidden variables
# Epoch     0, train loss 1.986442, train error 72.53,  test loss 1.924891, test error 74.07
# Epoch   100, train loss 0.085077, train error 0.12,  test loss 2.236945, test error 50.47
# Epoch   200, train loss 0.011945, train error 0.00,  test loss 3.016302, test error 49.42
# Epoch   300, train loss 0.005592, train error 0.00,  test loss 3.365599, test error 49.33
# Epoch   400, train loss 0.003495, train error 0.00,  test loss 3.586764, test error 49.62
# Epoch   500, train loss 0.002489, train error 0.00,  test loss 3.745867, test error 49.55
# Epoch   600, train loss 0.001907, train error 0.00,  test loss 3.870534, test error 49.53
# Epoch   700, train loss 0.001531, train error 0.00,  test loss 3.974213, test error 49.42
# Epoch   800, train loss 0.001272, train error 0.00,  test loss 4.061867, test error 49.20
# Epoch   900, train loss 0.001083, train error 0.00,  test loss 4.138484, test error 49.35
# Training model with 120 hidden variables
# Epoch     0, train loss 1.992808, train error 73.97,  test loss 1.928522, test error 75.35
# Epoch   100, train loss 0.054401, train error 0.03,  test loss 2.170420, test error 49.80
# Epoch   200, train loss 0.009882, train error 0.00,  test loss 2.778221, test error 49.97
# Epoch   300, train loss 0.004856, train error 0.00,  test loss 3.056343, test error 50.03
# Epoch   400, train loss 0.003100, train error 0.00,  test loss 3.233830, test error 49.95
# Epoch   500, train loss 0.002235, train error 0.00,  test loss 3.367195, test error 50.05
# Epoch   600, train loss 0.001726, train error 0.00,  test loss 3.470353, test error 50.22
# Epoch   700, train loss 0.001394, train error 0.00,  test loss 3.556512, test error 50.20
# Epoch   800, train loss 0.001164, train error 0.00,  test loss 3.629698, test error 50.22
# Epoch   900, train loss 0.000994, train error 0.00,  test loss 3.693767, test error 50.28
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952548, train error 72.78,  test loss 1.895953, test error 73.68
# Epoch   100, train loss 0.035250, train error 0.00,  test loss 2.149410, test error 48.67
# Epoch   200, train loss 0.007940, train error 0.00,  test loss 2.616978, test error 49.00
# Epoch   300, train loss 0.004108, train error 0.00,  test loss 2.836524, test error 49.03
# Epoch   400, train loss 0.002665, train error 0.00,  test loss 2.981135, test error 49.17
# Epoch   500, train loss 0.001942, train error 0.00,  test loss 3.090586, test error 49.05
# Epoch   600, train loss 0.001510, train error 0.00,  test loss 3.175091, test error 49.05
# Epoch   700, train loss 0.001227, train error 0.00,  test loss 3.246809, test error 49.05
# Epoch   800, train loss 0.001027, train error 0.00,  test loss 3.307327, test error 49.17
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.361112, test error 49.20
# Training model with 160 hidden variables
# Epoch     0, train loss 1.941338, train error 71.10,  test loss 1.867864, test error 72.43
# Epoch   100, train loss 0.027744, train error 0.00,  test loss 2.060102, test error 48.05
# Epoch   200, train loss 0.007003, train error 0.00,  test loss 2.458444, test error 48.72
# Epoch   300, train loss 0.003685, train error 0.00,  test loss 2.651598, test error 48.90
# Epoch   400, train loss 0.002420, train error 0.00,  test loss 2.780029, test error 48.72
# Epoch   500, train loss 0.001772, train error 0.00,  test loss 2.877140, test error 48.83
# Epoch   600, train loss 0.001385, train error 0.00,  test loss 2.954069, test error 48.88
# Epoch   700, train loss 0.001128, train error 0.00,  test loss 3.018094, test error 48.85
# Epoch   800, train loss 0.000947, train error 0.00,  test loss 3.073017, test error 48.78
# Epoch   900, train loss 0.000813, train error 0.00,  test loss 3.121112, test error 48.55
# Training model with 180 hidden variables
# Epoch     0, train loss 1.922203, train error 70.32,  test loss 1.853171, test error 72.32
# Epoch   100, train loss 0.024110, train error 0.00,  test loss 2.028777, test error 48.00
# Epoch   200, train loss 0.006590, train error 0.00,  test loss 2.380955, test error 48.20
# Epoch   300, train loss 0.003538, train error 0.00,  test loss 2.556295, test error 47.80
# Epoch   400, train loss 0.002347, train error 0.00,  test loss 2.675846, test error 47.92
# Epoch   500, train loss 0.001727, train error 0.00,  test loss 2.764597, test error 48.12
# Epoch   600, train loss 0.001353, train error 0.00,  test loss 2.835381, test error 48.12
# Epoch   700, train loss 0.001105, train error 0.00,  test loss 2.895071, test error 48.20
# Epoch   800, train loss 0.000930, train error 0.00,  test loss 2.945385, test error 48.20
# Epoch   900, train loss 0.000799, train error 0.00,  test loss 2.990193, test error 48.17
# Training model with 200 hidden variables
# Epoch     0, train loss 1.929022, train error 70.43,  test loss 1.861998, test error 71.30
# Epoch   100, train loss 0.021295, train error 0.00,  test loss 1.967893, test error 48.28
# Epoch   200, train loss 0.006095, train error 0.00,  test loss 2.271732, test error 47.80
# Epoch   300, train loss 0.003301, train error 0.00,  test loss 2.430526, test error 48.05
# Epoch   400, train loss 0.002203, train error 0.00,  test loss 2.536547, test error 48.03
# Epoch   500, train loss 0.001627, train error 0.00,  test loss 2.614742, test error 47.97
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.679483, test error 48.10
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.732898, test error 48.05
# Epoch   800, train loss 0.000879, train error 0.00,  test loss 2.778689, test error 48.08
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.818673, test error 48.03
# Training model with 250 hidden variables
# Epoch     0, train loss 1.891407, train error 68.35,  test loss 1.810153, test error 69.88
# Epoch   100, train loss 0.017033, train error 0.00,  test loss 1.942499, test error 46.58
# Epoch   200, train loss 0.005350, train error 0.00,  test loss 2.196944, test error 46.33
# Epoch   300, train loss 0.002979, train error 0.00,  test loss 2.333589, test error 46.28
# Epoch   400, train loss 0.002012, train error 0.00,  test loss 2.425759, test error 46.12
# Epoch   500, train loss 0.001498, train error 0.00,  test loss 2.496626, test error 46.10
# Epoch   600, train loss 0.001182, train error 0.00,  test loss 2.553895, test error 46.20
# Epoch   700, train loss 0.000970, train error 0.00,  test loss 2.601139, test error 46.28
# Epoch   800, train loss 0.000820, train error 0.00,  test loss 2.642669, test error 46.38
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.678359, test error 46.35
# Training model with 300 hidden variables
# Epoch     0, train loss 1.876611, train error 68.65,  test loss 1.821358, test error 70.32
# Epoch   100, train loss 0.014660, train error 0.00,  test loss 1.899721, test error 47.08
# Epoch   200, train loss 0.004837, train error 0.00,  test loss 2.118256, test error 47.15
# Epoch   300, train loss 0.002736, train error 0.00,  test loss 2.236953, test error 47.17
# Epoch   400, train loss 0.001859, train error 0.00,  test loss 2.318830, test error 47.00
# Epoch   500, train loss 0.001389, train error 0.00,  test loss 2.380201, test error 46.92
# Epoch   600, train loss 0.001100, train error 0.00,  test loss 2.430384, test error 46.95
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.472882, test error 46.92
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.509332, test error 46.85
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.541142, test error 46.85
# Training model with 400 hidden variables
# Epoch     0, train loss 1.833087, train error 65.18,  test loss 1.771511, test error 68.78
# Epoch   100, train loss 0.011519, train error 0.00,  test loss 1.794312, test error 45.80
# Epoch   200, train loss 0.004133, train error 0.00,  test loss 1.975781, test error 45.72
# Epoch   300, train loss 0.002394, train error 0.00,  test loss 2.073395, test error 45.72
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.143457, test error 45.75
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.196109, test error 45.70
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.238951, test error 45.58
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.275234, test error 45.70
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.306670, test error 45.65
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.333879, test error 45.67

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
